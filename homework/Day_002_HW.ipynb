# %%
Day 2 作業  

請下載本次馬拉松建議的 Kaggle 資料或準備好自己的資料
如採用 Kaggle 資料，請通過 HomeCredit_columns_description.csv，了解各個欄位的意義(csv檔可從檢視範例內的data資料夾下載)
請點下方檢視範例參考 Day_002_first_EDA.ipynb 檔案，了解如何讀取資料並可自行嘗試對資料進行操作，作業檔請提交Day_002_HW.ipynb

# %%
import os

import pandas as pd  #讀取CSV file，並所寫為pd
dir_data = 'C:/Users/user/Documents/GitHub/2nd-ML100Days/data/D2_sample'  #設定path

#data = pd.read_csv(dir_data_use[,'HomeCredit_columns_description.csv'])
f_app = os.path.join(dir_data, 'HomeCredit_columns_description.csv')
print('Path of read in data: %s' % (f_app))

data = pd.read_csv(os.path.join(dir_data, 'HomeCredit_columns_description_re.csv'))
#data = pd.read_csv('HomeCredit_columns_description_re.csv')  #注意python只能存取固定的編碼格式-->(UTF-8)
# https://blog.csdn.net/ssh5366/article/details/79419086
#fraw = pd.read_csv(dir_data, 'HomeCredit_columns_description.csv', encoding='utf-8))   #不知道哪裡不對
# Out:
# Path of read in data: C:/Users/user/Documents/GitHub/2nd-ML100Days/data/D2_sample\HomeCredit_columns_description.csv

# %%
data.head()  #用來觀察前 5 row (0~4)的資料
# Out:
#    Unnamed: 0                         Table                 Row  \
# 0           1  application_{train|test}.csv          SK_ID_CURR
# 1           2  application_{train|test}.csv              TARGET
# 2           5  application_{train|test}.csv  NAME_CONTRACT_TYPE
# 3           6  application_{train|test}.csv         CODE_GENDER
# 4           7  application_{train|test}.csv        FLAG_OWN_CAR
#
#                                          Description Special Unnamed: 5  \
# 0                           ID of loan in our sample     NaN        NaN
# 1  Target variable (1 - client with payment diffi...     NaN        NaN
# 2        Identification if loan is cash or revolving     NaN        NaN
# 3                               Gender of the client     NaN        NaN
# 4                      Flag if the client owns a car     NaN        NaN
#
#   Unnamed: 6
# 0        NaN
# 1        NaN
# 2        NaN
# 3        NaN
# 4        NaN

# %%
data.info()
#有四個變數 Table, Row, Description, Special

data.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 7 columns):
# Unnamed: 0     205 non-null int64
# Table          205 non-null object
# Row            205 non-null object
# Description    205 non-null object
# Special        80 non-null object
# Unnamed: 5     1 non-null object
# Unnamed: 6     1 non-null object
# dtypes: int64(1), object(6)
# memory usage: 11.3+ KB
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-18-0705ba291f01> in <module>
#       3
#       4 data.describe()
# ----> 5 data.shape()
#
# TypeError: 'tuple' object is not callable

# %%
print(data)
# Out:
#      Unnamed: 0                         Table                          Row  \
# 0             1  application_{train|test}.csv                   SK_ID_CURR
# 1             2  application_{train|test}.csv                       TARGET
# 2             5  application_{train|test}.csv           NAME_CONTRACT_TYPE
# 3             6  application_{train|test}.csv                  CODE_GENDER
# 4             7  application_{train|test}.csv                 FLAG_OWN_CAR
# 5             8  application_{train|test}.csv              FLAG_OWN_REALTY
# 6             9  application_{train|test}.csv                 CNT_CHILDREN
# 7            10  application_{train|test}.csv             AMT_INCOME_TOTAL
# 8            11  application_{train|test}.csv                   AMT_CREDIT
# 9            12  application_{train|test}.csv                  AMT_ANNUITY
# 10           13  application_{train|test}.csv              AMT_GOODS_PRICE
# ...

# %%
dir_data = 'C:/Users/user/Documents/GitHub/2nd-ML100Days/data/D2_sample'  #設定path

#data = pd.read_csv(dir_data_use[,'HomeCredit_columns_description.csv'])
a_app = os.path.join(dir_data, 'heart.csv')
print('Path of read in data: %s' % (a_app))
train = pd.read_csv(a_app)

#https://www.kaggle.com/ronitf/heart-disease-uci
# Out:
# Path of read in data: C:/Users/user/Documents/GitHub/2nd-ML100Days/data/D2_sample\heart.csv

# %%
train.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1
# 4   0     2       1

# %%
train.info()
#有14個變數，303個樣本
train.shape
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 303 entries, 0 to 302
# Data columns (total 14 columns):
# age         303 non-null int64
# sex         303 non-null int64
# cp          303 non-null int64
# trestbps    303 non-null int64
# chol        303 non-null int64
# fbs         303 non-null int64
# restecg     303 non-null int64
# thalach     303 non-null int64
# exang       303 non-null int64
# oldpeak     303 non-null float64
# slope       303 non-null int64
# ca          303 non-null int64
# thal        303 non-null int64
# target      303 non-null int64
# dtypes: float64(1), int64(13)
# memory usage: 33.2 KB
# (303, 14)

# %%
train.describe()  #資料中的數值計算:個數、平均數、標準差、最小值、最大值、四分位數
#?train.describe
# Out:
#               age         sex          cp    trestbps        chol         fbs  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean    54.366337    0.683168    0.966997  131.623762  246.264026    0.148515
# std      9.082101    0.466011    1.032052   17.538143   51.830751    0.356198
# min     29.000000    0.000000    0.000000   94.000000  126.000000    0.000000
# 25%     47.500000    0.000000    0.000000  120.000000  211.000000    0.000000
# 50%     55.000000    1.000000    1.000000  130.000000  240.000000    0.000000
# 75%     61.000000    1.000000    2.000000  140.000000  274.500000    0.000000
# max     77.000000    1.000000    3.000000  200.000000  564.000000    1.000000
#
#           restecg     thalach       exang     oldpeak       slope          ca  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean     0.528053  149.646865    0.326733    1.039604    1.399340    0.729373
# ...

# %%
train['sex'][0:303]
# Out:
# 0      1
# 1      1
# 2      0
# 3      1
# 4      0
# 5      1
# 6      0
# 7      1
# 8      1
# 9      1
# 10     1
# 11     0
# 12     1
# 13     1
# 14     0
# 15     0
# 16     0
# 17     0
# 18     1
# 19     0
# 20     1
# 21     1
# 22     1
# 23     1
# 24     1
# 25     0
# 26     1
# 27     1
# 28     0
# 29     1
#       ..
# 273    1
# 274    1
# 275    1
# 276    1
# 277    1
# 278    0
# 279    1
# 280    1
# 281    1
# 282    1
# 283    1
# 284    1
# 285    1
# 286    1
# 287    1
# 288    1
# 289    0
# 290    1
# 291    1
# 292    0
# 293    1
# 294    1
# 295    1
# 296    0
# 297    1
# 298    0
# 299    1
# 300    1
# 301    1
# 302    0
# Name: sex, Length: 303, dtype: int64

# %%
train_1 = train.insert(15,column = 'group', value = 'right')
train_1.head()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-44-a10d6d303cb5> in <module>
#       1 train_1 = train.insert(15,column = 'group', value = 'right')
# ----> 2 train_1.head()
#
# AttributeError: 'NoneType' object has no attribute 'head'

# %%
print(train[['sex']]) #列出sex變數

print(train[train['sex'] == 0]) #列出sex變數為0的項目
print(train[(train['sex'] == 0) & train['fbs'] == 1]) #列出sex變數為0 且fbs為1的項目
train.describe(train[train['sex']] == 0)
# Out:
#      sex
# 0      1
# 1      1
# 2      0
# 3      1
# 4      0
# 5      1
# 6      0
# 7      1
# 8      1
# 9      1
# 10     1
# 11     0
# 12     1
# 13     1
# 14     0
# 15     0
# 16     0
# 17     0
# 18     1
# 19     0
# 20     1
# 21     1
# 22     1
# 23     1
# 24     1
# 25     0
# 26     1
# 27     1
# 28     0
# 29     1
# ..   ...
# 273    1
# 274    1
# 275    1
# 276    1
# 277    1
# 278    0
# 279    1
# 280    1
# 281    1
# 282    1
# 283    1
# 284    1
# 285    1
# 286    1
# 287    1
# 288    1
# 289    0
# 290    1
# 291    1
# 292    0
# 293    1
# 294    1
# 295    1
# 296    0
# 297    1
# 298    0
# 299    1
# 300    1
# 301    1
# 302    0
#
# [303 rows x 1 columns]
#      age  sex    new  cp  trestbps  chol  fbs  restecg  thalach  exang  \
# 2     41    0  right   1       130   204    0        0      172      0
# 4     57    0  right   0       120   354    0        1      163      1
# ...
